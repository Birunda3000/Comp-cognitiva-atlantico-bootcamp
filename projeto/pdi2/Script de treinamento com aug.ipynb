# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import utils_img_rec as ut

import pathlib
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import layers, models, utils

import pickle
inicio = time.time()

# %% [markdown]
# ## Definindo Variaveis

# %%
BATCH_SIZE = 5000
EPOCHS = 50
IMG_SIZE = 32
numero_de_canais = 3
teste_treino = True

DATA_DIR = '../bases/pickle/imagens/cifar10/cifar10-train-pickle.pickle'

TEST_DIR = '../bases/pickle/imagens/cifar10/cifar10-test-pickle.pickle'

caminho_modelo = '../modelos_salvos/tensorflow/'
nome = 'modelo_cifar10' +'-aug-'+'EPOCHS='+str(EPOCHS)

DATA_DIR = pathlib.Path(DATA_DIR)
TEST_DIR = pathlib.Path(TEST_DIR)

# %% [markdown]
# ## Lendo e preparando os dados

# %%
pickle_in = open(DATA_DIR,"rb")
data_train = pickle.load(pickle_in)

# %%
if teste_treino:
    pickle_in = open(TEST_DIR,"rb")
    data_test = pickle.load(pickle_in)

# %%
CATEGORIES = ut.get_classes(data_train)
CATEGORIES.sort()
try:
    CATEGORIES.remove('.ipynb_checkpoints')
except:
    pass
print(CATEGORIES)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Exibindo amostra dos dados de treino

# %%
plt.figure(figsize=(10,10))
m = 70
if( len(data_train) < 70 ):
    m = len(data_train)
for i in range(m):
    plt.subplot(7,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(data_train[i][0], cmap='gray')
    plt.xlabel("{}\n({})".format( data_train[i][1] , data_train[i][2] ), color='white')    
plt.show()

# %% [markdown]
# ## Processo de aumento da base

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../Image-Augmentation/')

import Aug
import utils

# %%
pipe = Aug.Pipe()

pipe.add(Aug.Invert(prob=0.5))
pipe.add(Aug.Color(prob=0.6, min_factor=-3, max_factor=3))
pipe.add(Aug.Random_Erasing(prob=0.3, rectangle_area=0.3, repetitions=4))
pipe.add(Aug.Rotacao(prob=0.5, max_left_rotation=88, max_right_rotation=88, fill='edge'))
pipe.add(Aug.Shift(prob=0.5, horizontal_max=0.4, vertical_max=0.4, randomise=True, fill='nearest'))
pipe.add(Aug.Random_Noise(prob=0.5) )

pipe.print_pipe()
# Out:
# Operações:

# %%
data_train = utils.call_thread(data = data_train, pipe_instance = pipe, img_per_thread=5000, image_per_image = 2,
                               salvar_imagens_gerada=False)
# Out:
# Thread 6: Executada com sucesso
# Thread 3: Executada com sucesso
# Thread 8: Executada com sucesso
# Thread 5: Executada com sucesso
# Thread 9: Executada com sucesso
# Thread 4: Executada com sucesso
# Thread 0: Executada com sucesso
# Thread 2: Executada com sucesso
# Thread 1: Executada com sucesso
# Thread 7: Executada com sucesso

# %% [markdown]
# ### OBS: O codigo usado no aumento é parte de uma biblioteca ainda não finalizada
# #### Para mais informações sobre a biblioteca
# * https://github.com/Birunda3000/Image-Augmentation

# %% [markdown]
# ## Exibindo amostra dos dados de treino aumentados

# %%
utils.print_list_img(data_train, limite=40)
# Out:
# Numero imagens - 148281

# %% [markdown]
# ## Separando imagem e label e misturando dados

# %%
train_X, train_y = ut.prep_data(data_train, CATEGORIES, IMG_SIZE, numero_de_canais)
#print("Number of training images: ",len(data_train)
print('Entradas de treino - {} - ({}x{})'.format( train_X.shape[0], train_X.shape[1], train_X.shape[2] ))
# Out:
# Entradas de treino - 148281 - (32x32)

# %%
if teste_treino:
    test_X, test_y = ut.prep_data(data_test, CATEGORIES, IMG_SIZE, numero_de_canais)
    #print("Number of test images: ",len(data_test))
    print('Entradas de teste - {} - ({}x{})'.format( test_X.shape[0], test_X.shape[1], test_X.shape[2] ))
# Out:
# Entradas de teste - 10000 - (32x32)

# %% [markdown]
# ## Exibindo amostra dos dados de teste

# %%
plt.figure(figsize=(10,10))
m = 70
if( len(data_test) < 70 ):
    m = len(data_test)
for i in range(m):
    plt.subplot(7,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(data_test[i][0], cmap='gray')
    plt.xlabel("{}\n({})".format( data_test[i][1] , data_test[i][2] ), color='white')    
plt.show()

# %% [markdown]
# ## Normalizando dados

# %%
train_X=np.array(train_X/255.0)
train_y=np.array(train_y)
if teste_treino:
    test_X=np.array(test_X/255.0)
    test_y=np.array(test_y)

# %% [markdown]
# ## Modelo

# %%
model = models.Sequential()
model.add( layers.Conv2D(filters=32, kernel_size=(8, 8), activation='relu', input_shape=(test_X.shape[1:])))
model.add( layers.MaxPooling2D((2, 2)))

model.add( layers.Dropout(rate=0.2) )

model.add( layers.Conv2D(filters=16, kernel_size=(4, 4), activation='relu'))
model.add( layers.MaxPooling2D((2, 2)))

model.add( layers.Dropout(rate=0.2) )

#model.add( layers.Conv2D(filters=32, kernel_size=(2, 2), activation='relu'))
#model.add( layers.MaxPooling2D((2, 2)))

#model.add( layers.Dropout(rate=0.2) )

model.add( layers.Flatten( ) )
model.add( layers.Dense(60000, activation='relu') )
model.add( layers.Dropout(rate=0.4) )

model.add( layers.Dense(2000, activation='relu') )
model.add( layers.Dropout(rate=0.1) )

model.add( layers.Dense(128, activation='relu') )
model.add( layers.Dense(len(CATEGORIES) , activation='softmax') )

# %% [markdown]
# ## Realizando o treino

# %%
#opt = tf.keras.optimizers.SGD(
#    learning_rate=0.01, momentum=0.1, nesterov=False, name="SGD")
model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=['accuracy'])
if  teste_treino:
    history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(test_X, test_y))
else:
    history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=0.2)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 194s 6s/step - loss: 2.2944 - accuracy: 0.1194 - val_loss: 2.2117 - val_accuracy: 0.1912
# Epoch 2/50
# 30/30 [==============================] - 192s 6s/step - loss: 2.2378 - accuracy: 0.1576 - val_loss: 2.0862 - val_accuracy: 0.2405
# Epoch 3/50
# 30/30 [==============================] - 191s 6s/step - loss: 2.1622 - accuracy: 0.2007 - val_loss: 1.8995 - val_accuracy: 0.3320
# Epoch 4/50
# 30/30 [==============================] - 191s 6s/step - loss: 2.0701 - accuracy: 0.2448 - val_loss: 1.7079 - val_accuracy: 0.3926
# Epoch 5/50
# 30/30 [==============================] - 191s 6s/step - loss: 2.0084 - accuracy: 0.2698 - val_loss: 1.7544 - val_accuracy: 0.3834
# Epoch 6/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.9674 - accuracy: 0.2863 - val_loss: 1.5972 - val_accuracy: 0.4417
# Epoch 7/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.9157 - accuracy: 0.3092 - val_loss: 1.4999 - val_accuracy: 0.4691
# Epoch 8/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.8795 - accuracy: 0.3238 - val_loss: 1.4815 - val_accuracy: 0.4775
# Epoch 9/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.8506 - accuracy: 0.3338 - val_loss: 1.4098 - val_accuracy: 0.5110
# Epoch 10/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.8272 - accuracy: 0.3452 - val_loss: 1.3861 - val_accuracy: 0.5203
# Epoch 11/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.7889 - accuracy: 0.3590 - val_loss: 1.3791 - val_accuracy: 0.5198
# Epoch 12/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.7643 - accuracy: 0.3695 - val_loss: 1.3262 - val_accuracy: 0.5379
# Epoch 13/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.7466 - accuracy: 0.3762 - val_loss: 1.3417 - val_accuracy: 0.5445
# Epoch 14/50
# 30/30 [==============================] - 193s 6s/step - loss: 1.7163 - accuracy: 0.3876 - val_loss: 1.2837 - val_accuracy: 0.5593
# Epoch 15/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.6940 - accuracy: 0.3985 - val_loss: 1.2818 - val_accuracy: 0.5541
# Epoch 16/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.6677 - accuracy: 0.4074 - val_loss: 1.2547 - val_accuracy: 0.5639
# Epoch 17/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.6480 - accuracy: 0.4138 - val_loss: 1.2190 - val_accuracy: 0.5811
# Epoch 18/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.6234 - accuracy: 0.4233 - val_loss: 1.2418 - val_accuracy: 0.5688
# Epoch 19/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.6054 - accuracy: 0.4309 - val_loss: 1.2163 - val_accuracy: 0.5755
# Epoch 20/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.5784 - accuracy: 0.4403 - val_loss: 1.1878 - val_accuracy: 0.5885
# Epoch 21/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.5578 - accuracy: 0.4487 - val_loss: 1.2037 - val_accuracy: 0.5801
# Epoch 22/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.5262 - accuracy: 0.4612 - val_loss: 1.1905 - val_accuracy: 0.5945
# Epoch 23/50
# 30/30 [==============================] - 193s 6s/step - loss: 1.5205 - accuracy: 0.4640 - val_loss: 1.1969 - val_accuracy: 0.5852
# Epoch 24/50
# 30/30 [==============================] - 195s 7s/step - loss: 1.4758 - accuracy: 0.4798 - val_loss: 1.1577 - val_accuracy: 0.5996
# Epoch 25/50
# 30/30 [==============================] - 193s 6s/step - loss: 1.4425 - accuracy: 0.4924 - val_loss: 1.2005 - val_accuracy: 0.5897
# Epoch 26/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.4162 - accuracy: 0.5013 - val_loss: 1.1628 - val_accuracy: 0.6009
# Epoch 27/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.4070 - accuracy: 0.5066 - val_loss: 1.1920 - val_accuracy: 0.5901
# Epoch 28/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.3613 - accuracy: 0.5201 - val_loss: 1.1838 - val_accuracy: 0.5929
# Epoch 29/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.3328 - accuracy: 0.5324 - val_loss: 1.1893 - val_accuracy: 0.5942
# Epoch 30/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.2971 - accuracy: 0.5446 - val_loss: 1.1870 - val_accuracy: 0.6011
# Epoch 31/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.2595 - accuracy: 0.5582 - val_loss: 1.1917 - val_accuracy: 0.5929
# Epoch 32/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.2351 - accuracy: 0.5660 - val_loss: 1.1810 - val_accuracy: 0.5995
# Epoch 33/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.2069 - accuracy: 0.5766 - val_loss: 1.2010 - val_accuracy: 0.6002
# Epoch 34/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.1639 - accuracy: 0.5928 - val_loss: 1.2137 - val_accuracy: 0.5922
# Epoch 35/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.1339 - accuracy: 0.6025 - val_loss: 1.2003 - val_accuracy: 0.6043
# Epoch 36/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.1002 - accuracy: 0.6135 - val_loss: 1.2176 - val_accuracy: 0.5995
# Epoch 37/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.0659 - accuracy: 0.6269 - val_loss: 1.2375 - val_accuracy: 0.5957
# Epoch 38/50
# 30/30 [==============================] - 191s 6s/step - loss: 1.0393 - accuracy: 0.6346 - val_loss: 1.2585 - val_accuracy: 0.5957
# Epoch 39/50
# 30/30 [==============================] - 192s 6s/step - loss: 1.0012 - accuracy: 0.6504 - val_loss: 1.2586 - val_accuracy: 0.5888
# Epoch 40/50
# 30/30 [==============================] - 191s 6s/step - loss: 0.9702 - accuracy: 0.6594 - val_loss: 1.2648 - val_accuracy: 0.5950
# Epoch 41/50
# 30/30 [==============================] - 191s 6s/step - loss: 0.9373 - accuracy: 0.6715 - val_loss: 1.2580 - val_accuracy: 0.5983
# Epoch 42/50
# 30/30 [==============================] - 191s 6s/step - loss: 0.9113 - accuracy: 0.6815 - val_loss: 1.2835 - val_accuracy: 0.5946
# Epoch 43/50
# 30/30 [==============================] - 191s 6s/step - loss: 0.8745 - accuracy: 0.6947 - val_loss: 1.3132 - val_accuracy: 0.5935
# Epoch 44/50
# 30/30 [==============================] - 192s 6s/step - loss: 0.8442 - accuracy: 0.7075 - val_loss: 1.3125 - val_accuracy: 0.5911
# Epoch 45/50
# 30/30 [==============================] - 192s 6s/step - loss: 0.8338 - accuracy: 0.7095 - val_loss: 1.3420 - val_accuracy: 0.5863
# Epoch 46/50
# 30/30 [==============================] - 192s 6s/step - loss: 0.7970 - accuracy: 0.7238 - val_loss: 1.3416 - val_accuracy: 0.5924
# Epoch 47/50
# 30/30 [==============================] - 192s 6s/step - loss: 0.7739 - accuracy: 0.7310 - val_loss: 1.3362 - val_accuracy: 0.5951
# Epoch 48/50
# 30/30 [==============================] - 191s 6s/step - loss: 0.7496 - accuracy: 0.7394 - val_loss: 1.3717 - val_accuracy: 0.5865
# Epoch 49/50
# 30/30 [==============================] - 191s 6s/step - loss: 0.7337 - accuracy: 0.7450 - val_loss: 1.3555 - val_accuracy: 0.5880
# Epoch 50/50
# 30/30 [==============================] - 192s 6s/step - loss: 0.7030 - accuracy: 0.7565 - val_loss: 1.4043 - val_accuracy: 0.5922

# %% [markdown]
# ## Grafico do treino

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.45, 1])
plt.legend(loc='lower right')

# %%
test_loss, test_acc = model.evaluate(test_X, test_y, verbose=1)
print('Tempo de execução: ', time.time() - inicio)
# Out:
# 313/313 [==============================] - 9s 28ms/step - loss: 1.4043 - accuracy: 0.5922
# Tempo de execução:  9886.937153816223

# %%
nome_saida = caminho_modelo+nome+' - val_acc = '+   str(round(test_acc, 6))  + ' exec_time - '+ str(time.time() - inicio) + '.h5'
#nome_saida = caminho_modelo+nome+'.h5'

model.save(nome_saida)
print('Salvo como: ',nome_saida)
# Out:
# Salvo como:  ../modelos_salvos/tensorflow/modelo_cifar10-aug-EPOCHS=50 - val_acc = 0.5922 exec_time - 9886.943656682968.h5
