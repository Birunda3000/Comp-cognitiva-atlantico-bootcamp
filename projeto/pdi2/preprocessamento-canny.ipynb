# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import utils_img_rec as ut

import pathlib

import cv2
from cv2 import Canny

import pickle
inicio = time.time()

# %%
#DATADIR = r"..\..\..\_DATA_\image\face\faustao\faustao.jpg"
#DATADIR = "ratinho.jpg"

DATADIR = 'faustao.jpg'

path = pathlib.Path(DATADIR)
print(path)
# Out:
# faustao.jpg

# %%
img = cv2.imread(str(path) ,cv2.cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb, cmap='gray')
plt.show()

# %%
# nessa imagem i < 130 e j > 40

# %%
def canny_p(img):
    
    can = cv2.Canny(img, 60, 100)

    img_rgb = cv2.cvtColor(can, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb, cmap='gray')
    plt.show()
    return can

# %%
li = [1,  21, 41, 61,61, 80,100]
lj = [110,100,100,80,100,80,60]

for i in range(len(li)):

    print("i: ", li[i], "j: ", lj[i])
    can = cv2.Canny(img, li[i], lj[i])

    img_rgb = cv2.cvtColor(can, cv2.COLOR_BGR2RGB)

    plt.imshow(img_rgb, cmap='gray')
    plt.show()
# Out:
# i:  1 j:  110
# i:  21 j:  100
# i:  41 j:  100
# i:  61 j:  80
# i:  61 j:  100
# i:  80 j:  80
# i:  100 j:  60

# %%
li = [1,  21, 41, 61,61, 80,100]
lj = [110,100,100,80,100,80,60]

for i in li:
    for j in lj:

        
        print("i: ", i, "j: ", j)
        can = cv2.Canny(img, i, j)

        img_rgb = cv2.cvtColor(can, cv2.COLOR_BGR2RGB)

        plt.imshow(img_rgb, cmap='gray')
        plt.show()
# Out:
# i:  1 j:  110
# i:  1 j:  100
# i:  1 j:  100
# i:  1 j:  80
# i:  1 j:  100
# i:  1 j:  80
# i:  1 j:  60
# i:  21 j:  110
# i:  21 j:  100
# i:  21 j:  100
# i:  21 j:  80
# i:  21 j:  100
# i:  21 j:  80
# i:  21 j:  60
# i:  41 j:  110
# i:  41 j:  100
# i:  41 j:  100
# i:  41 j:  80
# i:  41 j:  100
# i:  41 j:  80
# i:  41 j:  60
# i:  61 j:  110
# i:  61 j:  100
# i:  61 j:  100
# i:  61 j:  80
# i:  61 j:  100
# i:  61 j:  80
# i:  61 j:  60
# i:  61 j:  110
# i:  61 j:  100
# i:  61 j:  100
# i:  61 j:  80
# i:  61 j:  100
# i:  61 j:  80
# i:  61 j:  60
# i:  80 j:  110
# i:  80 j:  100
# i:  80 j:  100
# i:  80 j:  80
# i:  80 j:  100
# i:  80 j:  80
# i:  80 j:  60
# i:  100 j:  110
# i:  100 j:  100
# i:  100 j:  100
# i:  100 j:  80
# i:  100 j:  100
# i:  100 j:  80
# i:  100 j:  60
