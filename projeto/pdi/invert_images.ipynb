# %%
import cv2
from pdi_utils import show_image
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu
import os
import pathlib
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np

# %%
DATADIR = '../../../_DATA_/Folhas_segmented'
OUTDIR = '../../../_DATA_/Folhas_invert'
DATADIR = pathlib.Path(DATADIR)
files = os.listdir(DATADIR)
files.sort(reverse=True)

# %%
for img in tqdm(files):
    path = os.path.join(DATADIR,img)
    out_path = os.path.join(OUTDIR,img+'-resize-semi-seg-inverted.jpg')
    imagem = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

    imagem = cv2.bitwise_not(imagem)
    #plt.imshow(np.array(imagem/255.0), cmap='gray')
    show_image(np.array(imagem/255.0))
    #plt.show()
    #show_image(binary)
    #plt.imshow(binary, cmap='gray')
    #plt.show()
    cv2.imwrite(out_path, imagem)
    print('-------------------')
# Out:
# ...
#   4%|▍         | 1/25 [00:00<00:04,  5.54it/s]
# -------------------
#   8%|▊         | 2/25 [00:00<00:04,  5.64it/s]
# -------------------
#  12%|█▏        | 3/25 [00:00<00:03,  5.94it/s]
# -------------------
#  16%|█▌        | 4/25 [00:00<00:03,  6.13it/s]
# -------------------
#  20%|██        | 5/25 [00:00<00:03,  6.23it/s]
# -------------------
#  24%|██▍       | 6/25 [00:00<00:03,  6.29it/s]
# -------------------
#  28%|██▊       | 7/25 [00:01<00:02,  6.30it/s]
# -------------------
#  32%|███▏      | 8/25 [00:01<00:02,  6.26it/s]
# -------------------
#  36%|███▌      | 9/25 [00:01<00:02,  5.56it/s]
# -------------------
#  40%|████      | 10/25 [00:01<00:02,  5.73it/s]
# -------------------
#  44%|████▍     | 11/25 [00:01<00:02,  5.90it/s]
# -------------------
#  48%|████▊     | 12/25 [00:02<00:02,  6.03it/s]
# -------------------
#  52%|█████▏    | 13/25 [00:02<00:01,  6.13it/s]
# -------------------
#  56%|█████▌    | 14/25 [00:02<00:01,  6.25it/s]
# -------------------
# ...
